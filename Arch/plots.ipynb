# %%
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
from T_method import LayeredStructure
from My_plotter import Plotter, Style
from Global_optimizer import my_json_load

# %%
st = Style()
fig, ax = plt.subplots()
pl1 = Plotter(ax, st)
seeds = [2, 5, 43, 90]
df = np.linspace(-50, 50, 200)/100
for seed in seeds:
    path = Path(f"temp/de_seed_{seed}.json")
    data = my_json_load(path)
    alpha = data["best_alpha"]
    beta = data["best_beta"]
    structure = LayeredStructure(alpha, beta=beta)
    directivity = 10*np.log10(structure.directivity(df))
    pl1.plot(df, directivity, label=f"18dBi, seed={seed}")
for seed in seeds:
    path = Path(f"temp/de_16_seed_{seed}.json")
    data = my_json_load(path)
    alpha = data["best_alpha"]
    beta = data["best_beta"]
    structure = LayeredStructure(alpha, beta=beta)
    directivity = 10*np.log10(structure.directivity(df))
    pl1.plot(df, directivity, label=f"16dBi, seed={seed}")
pl1.finalize()
pl1.set_ylim((0, 25))
ax.axhline(18, color='gray', linestyle='--', alpha=0.5)
ax.axhline(16, color='gray', linestyle='--', alpha=0.5)
ax.axvline(-0.11, color='gray', linestyle='--', alpha=0.5)
ax.axvline(0.15, color='gray', linestyle='--', alpha=0.5)
plt.show()

# %%
st = Style()
fig, ax = plt.subplots()
pl1 = Plotter(ax, st)
widths3 = []
thress = [14.0, 15.0, 16.0, 17.0, 18.0, 19.0, 20.0, 21.0, 22.0][::2]
pl1.set_p(thress)
df = np.linspace(-50, 50, 300)/100
for thr in thress:
    path = Path(f"kz/de_{thr}_seed_90.json")
    data = my_json_load(path)
    alpha = data["best_alpha"]
    beta = data["best_beta"]
    print(alpha, beta)
    structure = LayeredStructure(alpha, beta=beta)
    directivity = 10*np.log10(structure.directivity(df))
    l = 0
    while directivity[l] < thr:
        l += 1
    r = len(directivity)-1
    while directivity[r] < thr:
        r -= 1
    width = df[r] - df[l]
    widths3.append(width)
    pl1.multiple_plot(df*100, directivity, thr, label=f"{thr} дБи")
pl1.set_ylim((0, 26))
for thr in thress:
    ax.axhline(thr, color='gray', linestyle='--', alpha=0.5)
pl1.set_xlabel(r'$\Delta f/f_0$, %')
pl1.set_ylabel('КНД, дБи')
pl1.finalize()
plt.show()

# %%
# Эволюция диаграмм направленности (например с N=2) при alpha=1.5 и beta для максимального КУ c изменением частоты в E-плоскости.
st = Style()
fig, ax = plt.subplots()
pl1 = Plotter(ax, st)
alpha = np.array([17.730533451059966, 6.29681073580916, 1.9198566710355962])
beta = np.array([2.768701962101043, 2.777030033975197, 2.5262314160873536])
theta_arr = np.linspace(-np.pi/2*0.99, np.pi/2*0.99, 200)
df = np.linspace(-0.13, 0.13, 9)
pl1.set_p(df*100)
for df_i in df:
    structure = LayeredStructure(alpha, beta=beta)
    rad_pat = structure.radiation_pattern(np.array([0]), theta_arr, np.array([df_i]), mode='absolute')[0, 0, :]
    directivity = 10*np.log10(structure.directivity(np.array([df_i])))[0]
    pl1.multiple_plot(theta_arr*180/np.pi, 10*np.log10(rad_pat), df_i*100, label=f"$\\Delta f/f_0$={df_i*100:.1f}%")
pl1.set_xlabel('$\\theta^\\circ$')
pl1.set_ylabel('Диаграмма направленности, дБи')
pl1.set_ylim((-10, 30))
pl1.finalize()
plt.show()

# %%
st = Style()
fig, ax = plt.subplots()
pl1 = Plotter(ax, st)
pl1.plot(thress, np.array(widths3)*100)
pl1.set_xlabel('Directivity, dBi')
pl1.set_ylabel(r'Bandwidth, %')
pl1.finalize()
plt.show()

# %%
st = Style()
fig, ax = plt.subplots()
pl1 = Plotter(ax, st)
widths2 = []
thress = [14.0, 15.0, 16.0, 17.0, 18.0, 19.0, 20.0, 21.0, 22.0][::2]
pl1.set_p(thress)
df = np.linspace(-50, 50, 300)/100
for thr in thress:
    path = Path(f"kz/2sh/de_{thr}_seed_90.json")
    data = my_json_load(path)
    alpha = data["best_alpha"]
    beta = data["best_beta"]
    print(f"alpha = {alpha}\n" f"beta = {beta}")
    structure = LayeredStructure(alpha, beta=beta)
    directivity = 10*np.log10(structure.directivity(df))
    l = 0
    while directivity[l] < thr:
        l += 1
    r = len(directivity)-1
    while directivity[r] < thr:
        r -= 1
    width = df[r] - df[l]
    widths2.append(width)
    pl1.multiple_plot(df*100, directivity, thr, label=f"{thr} дБи")
pl1.set_ylim((0, 26))
for thr in thress:
    ax.axhline(thr, color='gray', linestyle='--', alpha=0.5)
pl1.set_xlabel(r'$\Delta f/f_0$, %')
pl1.set_ylabel('КНД, дБи')
pl1.finalize()
plt.show()

# %%
st = Style()
fig, ax = plt.subplots()
pl1 = Plotter(ax, st)
pl1.plot(thress, np.array(widths2)*100)
pl1.set_xlabel('Directivity, dBi')
pl1.set_ylabel(r'Bandwidth, %')
pl1.finalize()
plt.show()

# %%
st = Style()
fig, ax = plt.subplots()
pl1 = Plotter(ax, st)
widths4 = []
thress4 = [14.0, 15.0, 16.0, 17.0, 18.0, 19.0, 20.0, 21.0, 22.0][1::2]
pl1.set_p(thress4)
df = np.linspace(-50, 50, 300)/100
for thr in thress4:
    path = Path(f"kz/4sh/de_{thr}_seed_90.json")
    data = my_json_load(path)
    alpha = data["best_alpha"]
    beta = data["best_beta"]
    print(f"alpha = {alpha}\n" f"beta = {beta}")
    structure = LayeredStructure(alpha, beta=beta)
    directivity = 10*np.log10(structure.directivity(df))
    l = 0
    while directivity[l] < thr:
        l += 1
    r = len(directivity)-1
    while directivity[r] < thr:
        r -= 1
    width = df[r] - df[l]
    widths4.append(width)
    pl1.multiple_plot(df*100, directivity, thr, label=f"{thr} дБи")
pl1.set_ylim((0, 26))
for thr in thress4:
    ax.axhline(thr, color='gray', linestyle='--', alpha=0.5)
pl1.set_xlabel(r'$\Delta f/f_0$, %')
pl1.set_ylabel('КНД, дБи')
pl1.finalize()
ax.legend(loc='upper right')
plt.show()

# %%
st = Style()
fig, ax = plt.subplots()
pl1 = Plotter(ax, st)
pl1.plot(thress4, np.array(widths4)*100)
pl1.set_xlabel('Directivity, dBi')
pl1.set_ylabel(r'Bandwidth, %')
pl1.finalize()
plt.show()

# %%
st = Style()
fig, ax = plt.subplots()
pl1 = Plotter(ax, st)
widths1 = []
thress = [14.0, 15.0, 16.0, 17.0, 18.0, 19.0, 20.0, 21.0, 22.0][::2]
pl1.set_p(thress)
df = np.linspace(-50, 50, 300)/100
for thr in thress:
    path = Path(f"kz/1sh/de_{thr}_seed_90.json")
    data = my_json_load(path)
    alpha = data["best_alpha"]
    beta = data["best_beta"]
    structure = LayeredStructure(alpha, beta=beta)
    directivity = 10*np.log10(structure.directivity(df))
    l = 0
    while directivity[l] < thr:
        l += 1
    r = len(directivity)-1
    while directivity[r] < thr:
        r -= 1
    width = df[r] - df[l]
    widths1.append(width)
    pl1.multiple_plot(df*100, directivity, thr, label=f"{thr} дБи")
pl1.set_ylim((0, 26))
for thr in thress:
    ax.axhline(thr, color='gray', linestyle='--', alpha=0.5)
pl1.set_xlabel(r'$\Delta f/f_0$, %')
pl1.set_ylabel('КНД, дБи')
pl1.finalize()
plt.show()

# %%
st = Style()
fig, ax = plt.subplots()
pl1 = Plotter(ax, st)
pl1.plot(thress, np.array(widths1)*100, label="N = 1")
pl1.plot(thress, np.array(widths2)*100, label="N = 2")
pl1.plot(thress, np.array(widths3)*100, label="N = 3")
pl1.plot(thress4, np.array(widths4)*100, label="N = 4")
pl1.set_xlabel('Пороговое значение КНД, дБи')
pl1.set_ylabel(r'Максимальная полоса, %')
pl1.finalize()
plt.show()

# %%
# Диаграммы направленности для структур (например с N=2) при разных alpha и beta для максимального КУ на одной частоте в E-плоскости. 
st = Style()
fig, ax = plt.subplots()
pl1 = Plotter(ax, st)
alpha_arr = np.arange(0.5, 3.5, 0.5)
#alpha_arr = np.linspace(1.0, 7.0, 6)
pl1.set_p(alpha_arr)
theta_arr = np.linspace(-np.pi/2*0.99, np.pi/2*0.99, 200)
for alpha in alpha_arr:
    alpha_i = np.ones(2)*alpha
    structure = LayeredStructure(alpha_i, beta = "first_approx")
    rad_pat = structure.radiation_pattern(np.array([0]), theta_arr, np.array([0]), mode='absolute')[0, 0, :]
    directivity = 10*np.log10(structure.directivity(np.array([0])))[0]
    pl1.multiple_plot(theta_arr*180/np.pi, 10*np.log10(rad_pat), alpha, label=f"$\\alpha$={alpha:.1f}, D={directivity:.2f} дБи")
pl1.set_xlabel('$\\theta^\\circ$')
pl1.set_ylabel('Диаграмма направленности, дБи')
pl1.set_ylim((-10, 30))
pl1.finalize()
plt.show()

# %%
# Диаграммы направленности для структур (например с N=2) при разных alpha и beta для максимального КУ на одной частоте в H-плоскости. 
st = Style()
fig, ax = plt.subplots()
pl1 = Plotter(ax, st)
alpha_arr = np.arange(0.5, 3.5, 0.5)
#alpha_arr = np.linspace(1.0, 7.0, 6)
pl1.set_p(alpha_arr)
theta_arr = np.linspace(-np.pi/2*0.99, np.pi/2*0.99, 200)
for alpha in alpha_arr:
    alpha_i = np.ones(2)*alpha
    structure = LayeredStructure(alpha_i, beta = "first_approx")
    rad_pat = structure.radiation_pattern(np.array([np.pi/2]), theta_arr, np.array([0]), mode='absolute')[0, 0, :]
    directivity = 10*np.log10(structure.directivity(np.array([0])))[0]
    pl1.multiple_plot(theta_arr*180/np.pi, 10*np.log10(rad_pat), alpha, label=f"$\\alpha$={alpha:.1f}, D={directivity:.2f} дБи")
pl1.set_xlabel('$\\theta^\\circ$')
pl1.set_ylabel('Диаграмма направленности, дБи')
pl1.set_ylim((-10, 30))
pl1.finalize()
plt.show()

# %%
# Дисперсионные характеристики для структур (например с N=2) при разных alpha и beta для максимального КУ на одной частоте.
st = Style()
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
pl1 = Plotter(ax[0], st)
pl2 = Plotter(ax[1], st)
alpha_arr = np.arange(0.5, 3.5, 0.5)
#alpha_arr = np.linspace(1.0, 7.0, 6)
pl1.set_p(alpha_arr)
pl2.set_p(alpha_arr)
df = np.linspace(-10, 10, 200)/100
for alpha in alpha_arr:
    alpha_i = np.ones(2)*alpha
    structure = LayeredStructure(alpha_i, beta = "first_approx")
    directivity = 10*np.log10(structure.directivity(df))
    directivity_naive = 10*np.log10(structure.directivity_naive(df))
    pl1.multiple_plot(df*100, directivity, alpha, label=f"$\\alpha$={alpha:.1f}")
    pl2.multiple_plot(df*100, directivity_naive+6, alpha, label=f"$\\alpha$={alpha:.1f}", linestyle='-')
pl1.set_xlabel(r'$\Delta f/f_0$, %')
pl1.set_ylabel('КНД, дБи')
pl1.set_ylim((5, 30))
pl1.finalize()
pl2.set_xlabel(r'$\Delta f/f_0$, %')
pl2.set_ylabel('$2\\kappa$, дБ')
pl2.set_ylim((5, 30))
pl2.finalize()
plt.show()

# %%
# Отдельно Дисперсионные характеристики для структур (например с N=2) при разных alpha и beta для максимального КУ на одной частоте.
st = Style()
fig, ax = plt.subplots()
pl1 = Plotter(ax, st)
alpha = 1.5
beta = "first_approx"
df = np.linspace(-10, 10, 200)/100
alpha_arr = np.arange(0.5, 3.5, 0.5)
pl1.set_p(alpha_arr)
for alpha_i in alpha_arr:
    alpha_i = np.ones(2)*alpha_i
    structure = LayeredStructure(alpha_i, beta=beta)
    directivity = 10*np.log10(structure.directivity(df))
    pl1.multiple_plot(df*100, directivity, alpha_i[0], label=f"α={alpha_i[0]}")
pl1.set_xlabel(r'$\Delta f/f_0$, %')
pl1.set_ylabel('КНД, дБи')
pl1.set_ylim((5, 35))
pl1.finalize()
pl1.set_ylim((5, 30))
plt.show()

# %%
# Дисперсионные характеристики для структур (например с N=2) при разных alpha и beta для максимального КУ на одной частоте.
st = Style()
fig, ax = plt.subplots()
pl1 = Plotter(ax, st)
alpha_arr = np.arange(0.5, 3.5, 0.5)
#alpha_arr = np.linspace(1.0, 7.0, 6)
pl1.set_p(alpha_arr)
df = np.linspace(-10, 10, 200)/100
for alpha in alpha_arr:
    alpha_i = np.ones(2)*alpha
    structure = LayeredStructure(alpha_i, beta = "first_approx")
    directivity = 10*np.log10(structure.directivity(df))
    directivity_naive = 10*np.log10(structure.directivity_naive(df))
    pl1.multiple_plot(df*100, directivity, alpha, label=f"$\\alpha$={alpha:.1f}")
    pl1.multiple_plot(df*100, directivity_naive+6.5, alpha, label=f"$\\alpha$={alpha:.1f}", linestyle='--')
pl1.set_xlabel(r'$\Delta f/f_0$, %')
pl1.set_ylabel('КНД, dBi')
pl1.set_ylim((5, 30))
pl1.finalize()
plt.show()

# %%
# Эволюция диаграмм направленности (например с N=2) при alpha=1.5 и beta для максимального КУ c изменением частоты в E-плоскости.
st = Style()
fig, ax = plt.subplots()
pl1 = Plotter(ax, st)
alpha = np.ones(2)*1.5
beta = "first_approx"
theta_arr = np.linspace(-np.pi/2*0.99, np.pi/2*0.99, 200)
df = np.linspace(-0.1, 0.1, 7)
pl1.set_p(df*100)
for df_i in df:
    structure = LayeredStructure(alpha, beta=beta)
    rad_pat = structure.radiation_pattern(np.array([0]), theta_arr, np.array([df_i]), mode='absolute')[0, 0, :]
    directivity = 10*np.log10(structure.directivity(np.array([df_i])))[0]
    pl1.multiple_plot(theta_arr*180/np.pi, 10*np.log10(rad_pat), df_i*100, label=f"$\\Delta f/f_0$={df_i*100:.1f}%")
pl1.set_xlabel('$\\theta^\\circ$')
pl1.set_ylabel('Диаграмма направленности, дБи')
pl1.set_ylim((-10, 30))
pl1.finalize()
plt.show()

# %%
# Диаграммы направленности для структур сразным количеством (для примера одинаковых) листов при alpha =1.5 и beta для максимального КУ на одной частоте в E-плоскости.
st = Style()
fig, ax = plt.subplots()
pl1 = Plotter(ax, st)
alpha = 1.5
beta = "first_approx"
theta_arr = np.linspace(-np.pi/2*0.99, np.pi/2*0.99, 200)
N = [1, 2, 3, 4]
pl1.set_p(N)
for N_i in N:
    alpha_i = np.ones(N_i)*alpha
    structure = LayeredStructure(alpha_i, beta=beta)
    rad_pat = structure.radiation_pattern(np.array([0]), theta_arr, np.array([0]), mode='absolute')[0, 0, :]
    directivity = 10*np.log10(structure.directivity(np.array([0])))[0]
    pl1.multiple_plot(theta_arr*180/np.pi, 10*np.log10(rad_pat), N_i, label=f"N={N_i}, D={directivity:.2f} дБи")
pl1.set_xlabel('$\\theta^\\circ$')
pl1.set_ylabel('Диаграмма направленности, дБи')
pl1.set_ylim((-10, 35))
pl1.finalize()
plt.show()

# %%
# Дисперсионные характеристики для структур сразным количеством (для примера одинаковых) листов при alpha =1.5 и beta для максимального КУ на одной частоте.
st = Style()
fig, ax = plt.subplots()
pl1 = Plotter(ax, st)
alpha = 1.5
beta = "first_approx"
df = np.linspace(-10, 10, 200)/100
N = [1, 2, 3, 4]
pl1.set_p(N)
for N_i in N:
    alpha_i = np.ones(N_i)*alpha
    structure = LayeredStructure(alpha_i, beta=beta)
    directivity = 10*np.log10(structure.directivity(df))
    pl1.multiple_plot(df*100, directivity, N_i, label=f"N={N_i}")
pl1.set_xlabel(r'$\Delta f/f_0$, %')
pl1.set_ylabel('КНД, дБи')
pl1.set_ylim((5, 35))
pl1.finalize()
plt.show()

# %%
from Global_optimizer import OptimizationParameters

# %%
opt_p = OptimizationParameters()
opt_p.show_sigma_penalty()
